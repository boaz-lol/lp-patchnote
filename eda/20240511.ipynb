# %%
import requests
import json

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_file_path = "/Users/hwanghyejeong/Documents/boaz/lp-patchnote/user_1_match_10.csv"
df = pd.read_csv(csv_file_path)

# %%
print("Descriptive Statistics for numeric columns:")
print(df.describe())
print("\n")
# Out:
# Descriptive Statistics for numeric columns:
#        Unnamed: 0       puuid        role  championId  champLevel  \
# count  112.000000  112.000000  112.000000  112.000000  112.000000
# mean    55.500000   42.669643    3.303571  179.357143   16.544643
# std     32.475632   24.584617    1.191859  240.979303    1.759855
# min      0.000000    0.000000    0.000000    2.000000   13.000000
# 25%     27.750000   22.750000    3.000000   34.750000   15.000000
# 50%     55.500000   40.500000    4.000000   83.500000   16.500000
# 75%     83.250000   65.250000    4.000000  201.000000   18.000000
# max    111.000000   83.000000    4.000000  950.000000   23.000000
#
#        damages_per_minute  damageTakenOnTeamPercentage  goldPerMinute  \
# count          112.000000                   112.000000     112.000000
# mean          1517.648387                     0.178571     638.809240
# std            699.782586                     0.068885     147.016059
# ...

# %%
print("Role distribution:")
print(df['role'].value_counts())
print("\n")
# Out:
# Role distribution:
# role
# 4    80
# 1    15
# 2    10
# 3     5
# 0     2
# Name: count, dtype: int64

# %%
print("Champion distribution:")
print(df['championId'].value_counts())
print("\n")
# Out:
# Champion distribution:
# championId
# 517    3
# 29     3
# 115    2
# 145    2
# 3      2
#       ..
# 27     1
# 57     1
# 78     1
# 147    1
# 902    1
# Name: count, Length: 85, dtype: int64

# %%
print("Champion distribution:")
print(df['puuid'].value_counts())
print("\n")
# Out:
# Champion distribution:
# puuid
# 40    10
# 4      5
# 75     5
# 76     5
# 42     3
#       ..
# 83     1
# 35     1
# 81     1
# 22     1
# 64     1
# Name: count, Length: 84, dtype: int64

# %%
print(df['win'].value_counts())
print("\n")
# Out:
# win
# True     56
# False    56
# Name: count, dtype: int64

# %%
df[['champLevel', 'damages_per_minute', 'damageTakenOnTeamPercentage', 'goldPerMinute', 'teamDamagePercentage', 'kda']].hist(bins=15, figsize=(15, 10))
plt.suptitle("Histograms of numeric columns")
plt.show()

# %%
df[['champLevel', 'damages_per_minute', 'damageTakenOnTeamPercentage', 'goldPerMinute', 'teamDamagePercentage', 'kda']].hist(bins=15, figsize=(15, 10))
plt.suptitle("Histograms of numeric columns")
plt.show()
